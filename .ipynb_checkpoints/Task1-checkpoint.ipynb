# %%
#Importing all the necessary libraries
import pandas as pd        # for tables
import numpy as np         # for numbers and math
import matplotlib.pyplot as plt   # for drawing graphs
import seaborn as sns      
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
#loading the dataset
df = pd.read_csv("heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
print("shape:", df.shape)
# Out:
# shape: (1025, 14)

# %%
print("column names:", df.columns.tolist())
# Out:
# column names: ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']

# %%
print("column data types:", df.dtypes)
# Out:
# column data types: age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
print("Missing values:", df.isnull().sum())
# Out:
# Missing values: age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
# Looping through each column 
for x in df.columns:
    print(f"Column '{x}' has {df[x].nunique()} unique values")
# Out:
# Column 'age' has 41 unique values
# Column 'sex' has 2 unique values
# Column 'cp' has 4 unique values
# Column 'trestbps' has 49 unique values
# Column 'chol' has 152 unique values
# Column 'fbs' has 2 unique values
# Column 'restecg' has 3 unique values
# Column 'thalach' has 91 unique values
# Column 'exang' has 2 unique values
# Column 'oldpeak' has 40 unique values
# Column 'slope' has 3 unique values
# Column 'ca' has 5 unique values
# Column 'thal' has 4 unique values
# Column 'target' has 2 unique values

# %%
df['target'].value_counts().plot(kind='bar', color=['blue', 'red'])
plt.title("Heart Disease Distribution Bar Chart")
plt.xlabel("0 = No Disease, 1 = Has Disease")
plt.ylabel("Number of Patients")
plt.xticks(rotation=0)
plt.show()

# %%
X = df.drop('target', axis=1)  # all the columns except target
y = df['target']               # only the target column

print("Features shape:", X.shape)
print("Target shape:", y.shape)
print("Feature columns:", X.columns.tolist())
# Out:
# Features shape: (1025, 13)
# Target shape: (1025,)
# Feature columns: ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal']

# %%
# Scaling puts everything on the same level
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print("Before scaling the age mean is:", X['age'].mean().round(2))
print("After scaling the age mean is:", X_scaled[:, 0].mean().round(2))
# Out:
# Before scaling the age mean is: 54.43
# After scaling the age mean is: -0.0

# %%
# Split 1: 80% train and 20% test
X_train_80, X_test_80, y_train_80, y_test_80 = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42)

# Split 2: 70% train and 30% test
X_train_70, X_test_70, y_train_70, y_test_70 = train_test_split(
    X_scaled, y, test_size=0.3, random_state=42)

# Split 3: 75% train and 25% test
X_train_75, X_test_75, y_train_75, y_test_75 = train_test_split(
    X_scaled, y, test_size=0.25, random_state=42)

print("Split 80/20 Train:", X_train_80.shape, "Test:", X_test_80.shape)
print("Split 70/30 Train:", X_train_70.shape, "Test:", X_test_70.shape)
print("Split 75/25 Train:", X_train_75.shape, "Test:", X_test_75.shape)
# Out:
# Split 80/20 Train: (820, 13) Test: (205, 13)
# Split 70/30 Train: (717, 13) Test: (308, 13)
# Split 75/25 Train: (768, 13) Test: (257, 13)

# %%
#Model 1: Logistic Regression
model_1 = LogisticRegression(random_state=42)

# Test on 80/20 split
model_1.fit(X_train_80, y_train_80)
pred_80 = model_1.predict(X_test_80)
acc_80 = accuracy_score(y_test_80, pred_80)

# Test on 70/30 split
model_1.fit(X_train_70, y_train_70)
pred_70 = model_1.predict(X_test_70)
acc_70 = accuracy_score(y_test_70, pred_70)

# Test on 75/25 split
model_1.fit(X_train_75, y_train_75)
pred_75 = model_1.predict(X_test_75)
acc_75 = accuracy_score(y_test_75, pred_75)

print("Model 1:Logistic Regression Results:")
print(f"80/20 split accuracy: {acc_80:.4f}")
print(f"70/30 split accuracy: {acc_70:.4f}")
print(f"75/25 split accuracy: {acc_75:.4f}")
# Out:
# Model 1:Logistic Regression Results:
# 80/20 split accuracy: 0.7951
# 70/30 split accuracy: 0.8052
# 75/25 split accuracy: 0.7899

# %%
#Classification Report
# Using the 70/30 since it performed the best
model_1.fit(X_train_70, y_train_70)
pred_70 = model_1.predict(X_test_70)

print("Detailed Classification Report (70/30 split):")
print(classification_report(y_test_70, pred_70,
      target_names=['No Disease', 'Has Disease']))
# Out:
# Detailed Classification Report (70/30 split):
#               precision    recall  f1-score   support
#
#   No Disease       0.86      0.75      0.80       159
#  Has Disease       0.76      0.87      0.81       149
#
#     accuracy                           0.81       308
#    macro avg       0.81      0.81      0.80       308
# weighted avg       0.81      0.81      0.80       308

# %%
cm = confusion_matrix(y_test_70, pred_70)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['No Disease', 'Has Disease'],
            yticklabels=['No Disease', 'Has Disease'])
plt.title('Logistic Regression - Confusion Matrix (70/30 split)')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=5)  # 5 nearest neighbours

# 80/20 split
knn.fit(X_train_80, y_train_80)
knn_pred_80 = knn.predict(X_test_80)
knn_acc_80 = accuracy_score(y_test_80, knn_pred_80)

# 70/30 split
knn.fit(X_train_70, y_train_70)
knn_pred_70 = knn.predict(X_test_70)
knn_acc_70 = accuracy_score(y_test_70, knn_pred_70)

# 75/25 split
knn.fit(X_train_75, y_train_75)
knn_pred_75 = knn.predict(X_test_75)
knn_acc_75 = accuracy_score(y_test_75, knn_pred_75)

print("KNN Results:")
print(f"80/20 split accuracy: {knn_acc_80:.4f}")
print(f"70/30 split accuracy: {knn_acc_70:.4f}")
print(f"75/25 split accuracy: {knn_acc_75:.4f}")
# Out:
# KNN Results:
# 80/20 split accuracy: 0.8341
# 70/30 split accuracy: 0.8571
# 75/25 split accuracy: 0.8288

# %%
# Using the 70/30 since it performed the best
knn.fit(X_train_70, y_train_70)
knn_pred_70 = knn.predict(X_test_70)

print("KNN Detailed Classification Report (70/30 split):")
print(classification_report(y_test_70, knn_pred_70,
      target_names=['No Disease', 'Has Disease']))
# Out:
# KNN Detailed Classification Report (70/30 split):
#               precision    recall  f1-score   support
#
#   No Disease       0.87      0.85      0.86       159
#  Has Disease       0.84      0.87      0.85       149
#
#     accuracy                           0.86       308
#    macro avg       0.86      0.86      0.86       308
# weighted avg       0.86      0.86      0.86       308

# %%
cm_knn = confusion_matrix(y_test_70, knn_pred_70)

sns.heatmap(cm_knn, annot=True, fmt='d', cmap='Greens',
            xticklabels=['No Disease', 'Has Disease'],
            yticklabels=['No Disease', 'Has Disease'])
plt.title('KNN - Confusion Matrix (70/30 split)')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
dt = DecisionTreeClassifier(random_state=42)

# 80/20 split
dt.fit(X_train_80, y_train_80)
dt_pred_80 = dt.predict(X_test_80)
dt_acc_80 = accuracy_score(y_test_80, dt_pred_80)

# 70/30 split
dt.fit(X_train_70, y_train_70)
dt_pred_70 = dt.predict(X_test_70)
dt_acc_70 = accuracy_score(y_test_70, dt_pred_70)

# 75/25 split
dt.fit(X_train_75, y_train_75)
dt_pred_75 = dt.predict(X_test_75)
dt_acc_75 = accuracy_score(y_test_75, dt_pred_75)

print("Decision Tree Results:")
print(f"80/20 split accuracy: {dt_acc_80:.4f}")
print(f"70/30 split accuracy: {dt_acc_70:.4f}")
print(f"75/25 split accuracy: {dt_acc_75:.4f}")
# Out:
# Decision Tree Results:
# 80/20 split accuracy: 0.9854
# 70/30 split accuracy: 0.9708
# 75/25 split accuracy: 0.9767

# %%
dt.fit(X_train_70, y_train_70)
dt_pred_70 = dt.predict(X_test_70)

print("Decision Tree Detailed Classification Report (70/30 split):")
print(classification_report(y_test_70, dt_pred_70,
      target_names=['No Disease', 'Has Disease']))
# Out:
# Decision Tree Detailed Classification Report (70/30 split):
#               precision    recall  f1-score   support
#
#   No Disease       0.95      1.00      0.97       159
#  Has Disease       1.00      0.94      0.97       149
#
#     accuracy                           0.97       308
#    macro avg       0.97      0.97      0.97       308
# weighted avg       0.97      0.97      0.97       308

# %%
# Limiting how deep the tree can grow to prevent memorising
dt_tuned = DecisionTreeClassifier(random_state=42, max_depth=5)

# 80/20 split
dt_tuned.fit(X_train_80, y_train_80)
dt_tuned_pred_80 = dt_tuned.predict(X_test_80)
dt_tuned_acc_80 = accuracy_score(y_test_80, dt_tuned_pred_80)

# 70/30 split
dt_tuned.fit(X_train_70, y_train_70)
dt_tuned_pred_70 = dt_tuned.predict(X_test_70)
dt_tuned_acc_70 = accuracy_score(y_test_70, dt_tuned_pred_70)

# 75/25 split
dt_tuned.fit(X_train_75, y_train_75)
dt_tuned_pred_75 = dt_tuned.predict(X_test_75)
dt_tuned_acc_75 = accuracy_score(y_test_75, dt_tuned_pred_75)

print("Decision Tree (max_depth=5) Results:")
print(f"80/20 split accuracy: {dt_tuned_acc_80:.4f}")
print(f"70/30 split accuracy: {dt_tuned_acc_70:.4f}")
print(f"75/25 split accuracy: {dt_tuned_acc_75:.4f}")
# Out:
# Decision Tree (max_depth=5) Results:
# 80/20 split accuracy: 0.8439
# 70/30 split accuracy: 0.8442
# 75/25 split accuracy: 0.8249

# %%
dt_tuned.fit(X_train_70, y_train_70)
dt_tuned_pred_70 = dt_tuned.predict(X_test_70)

print("Decision Tree (max_depth=5) Classification Report (70/30 split):")
print(classification_report(y_test_70, dt_tuned_pred_70,
      target_names=['No Disease', 'Has Disease']))
# Out:
# Decision Tree (max_depth=5) Classification Report (70/30 split):
#               precision    recall  f1-score   support
#
#   No Disease       0.95      0.74      0.83       159
#  Has Disease       0.77      0.96      0.86       149
#
#     accuracy                           0.84       308
#    macro avg       0.86      0.85      0.84       308
# weighted avg       0.86      0.84      0.84       308

# %%
# Decision Tree Confusion Matrix
cm_dt = confusion_matrix(y_test_70, dt_tuned_pred_70)

sns.heatmap(cm_dt, annot=True, fmt='d', cmap='Oranges',
            xticklabels=['No Disease', 'Has Disease'],
            yticklabels=['No Disease', 'Has Disease'])
plt.title('Decision Tree (max_depth=5) - Confusion Matrix (70/30 split)')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
# Final comparison bar chart
models = ['Logistic Regression', 'KNN', 'Decision Tree']
accuracies = [acc_70, knn_acc_70, dt_tuned_acc_70]
recalls = [0.87, 0.87, 0.96]  # Has Disease recall for each model

x = np.arange(len(models))
width = 0.35

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - width/2, accuracies, width, label='Accuracy', color='steelblue')
bars2 = ax.bar(x + width/2, recalls, width, label='Has Disease Recall', color='salmon')

ax.set_xlabel('Models')
ax.set_ylabel('Score')
ax.set_title('Model Comparison - Accuracy vs Has Disease Recall')
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.legend()
ax.set_ylim(0, 1.1)

# Add value labels on bars
for bar in bars1:
    ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 0.01,
            f'{bar.get_height():.2f}', ha='center', va='bottom')
for bar in bars2:
    ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 0.01,
            f'{bar.get_height():.2f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
summary = pd.DataFrame({
    'Model': ['Logistic Regression', 'KNN', 'Decision Tree'],
    'Best Split': ['70/30', '70/30', '70/30'],
    'Accuracy': [0.8052, 0.8571, 0.8442],
    'Has Disease Recall': [0.87, 0.87, 0.96],
    'F1 Score': [0.80, 0.86, 0.84],
    'Overfitting Risk': ['Low', 'Low', 'Medium (needs max_depth)']
})

print("FINAL MODEL COMPARISON - HEART DISEASE PREDICTION")
print(summary.to_string(index=False))
print("\nConclusion:")
print("1. Best overall accuracy: KNN (0.8571)")
print("2. Best at catching sick patients: Decision Tree (recall 0.96)")
print("3. Most stable and simple: Logistic Regression")
print("4. Recommended for medical use: Decision Tree (max_depth=5)")
# Out:
# FINAL MODEL COMPARISON - HEART DISEASE PREDICTION
#               Model Best Split  Accuracy  Has Disease Recall  F1 Score         Overfitting Risk
# Logistic Regression      70/30    0.8052                0.87      0.80                      Low
#                 KNN      70/30    0.8571                0.87      0.86                      Low
#       Decision Tree      70/30    0.8442                0.96      0.84 Medium (needs max_depth)
#
# Conclusion:
# 1. Best overall accuracy: KNN (0.8571)
# 2. Best at catching sick patients: Decision Tree (recall 0.96)
# 3. Most stable and simple: Logistic Regression
# 4. Recommended for medical use: Decision Tree (max_depth=5)

# %%
import pickle

# Retrain all 3 models with best settings (70/30 split)
# Logistic Regression
lr_final = LogisticRegression(random_state=42)
lr_final.fit(X_train_70, y_train_70)

# KNN
knn_final = KNeighborsClassifier(n_neighbors=5)
knn_final.fit(X_train_70, y_train_70)

# Decision Tree with max_depth=5 to prevent overfitting
dt_final = DecisionTreeClassifier(random_state=42, max_depth=5)
dt_final.fit(X_train_70, y_train_70)

# Save all 3 models and the scaler
with open('lr_model.pkl', 'wb') as f:
    pickle.dump(lr_final, f)

with open('knn_model.pkl', 'wb') as f:
    pickle.dump(knn_final, f)

with open('dt_model.pkl', 'wb') as f:
    pickle.dump(dt_final, f)

with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

print("All 3 models and scaler saved successfully!")
print("Files created: lr_model.pkl, knn_model.pkl, dt_model.pkl, scaler.pkl")
# Out:
# All 3 models and scaler saved successfully!
# Files created: lr_model.pkl, knn_model.pkl, dt_model.pkl, scaler.pkl

# %%
# Save model comparison results as CSV
results_df = pd.DataFrame({
    'Model': ['Logistic Regression', 'KNN', 'Decision Tree'],
    'Best_Split': ['70/30', '70/30', '70/30'],
    'Accuracy': [0.8052, 0.8571, 0.8442],
    'Has_Disease_Recall': [0.87, 0.87, 0.96],
    'No_Disease_Recall': [0.75, 0.85, 0.74],
    'F1_Score': [0.80, 0.86, 0.84],
    'Overfitting_Risk': ['Low', 'Low', 'Medium (needs max_depth)'],
    'Best_For': ['Simple Baseline', 'Overall Accuracy', 'Medical Safety']
})

results_df.to_csv('model_comparison_results.csv', index=False)
print("Results saved to model_comparison_results.csv!")
print(results_df)
# Out:
# Results saved to model_comparison_results.csv!
#                  Model Best_Split  Accuracy  Has_Disease_Recall  \
# 0  Logistic Regression      70/30    0.8052                0.87
# 1                  KNN      70/30    0.8571                0.87
# 2        Decision Tree      70/30    0.8442                0.96
#
#    No_Disease_Recall  F1_Score          Overfitting_Risk          Best_For
# 0               0.75      0.80                       Low   Simple Baseline
# 1               0.85      0.86                       Low  Overall Accuracy
# 2               0.74      0.84  Medium (needs max_depth)    Medical Safety
